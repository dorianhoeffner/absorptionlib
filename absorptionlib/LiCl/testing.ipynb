# %%
import functions as LiCl
import numpy as np
import matplotlib.pyplot as plt

# %%
LiCl.specific_heat_capacity(0.3, 20)
# Out:
# 2.9153294142737187

# %%
LiCl.diffusion_coefficient(0.2, 30)
# Out:
# 1.2173928714133192e-09

# %%
LiCl.dynamic_viscosity(0.2, 30)
# Out:
# 2.168187822484257

# %%
x_array = np.linspace(0.01, 0.3, 100)
cp = [LiCl.specific_heat_capacity(x, 26.5) for x in x_array]
plt.plot(x_array, cp, label="T=26.5°C")

# %%
x_array = np.linspace(0.01, 0.55, 100)
hd = [LiCl.differential_enthalpy_AD(x, 100) for x in x_array]
plt.plot(x_array, hd)

# %%
LiCl.saturation_pressure(0.3, 20)
# Out:
# 970.8232575409631

# %%
LiCl.saturation_temperature(0.3, 970.8232575409631)
# Out:
# 20.0

# %%
LiCl.saturation_concentration(970.8232575409631, 20)
# Out:
# 0.30000000000000004

# %%
LiCl.crystallization_curve()

# %%
x_array = np.linspace(0.01, 0.56, 100)
rho = [LiCl.density(x, 100) for x in x_array]
xvals = [x/(1-x) for x in x_array]
plt.plot(xvals, rho)
plt.grid()

# %%
LiCl.pTDiagram()

# %%
x_array = np.linspace(0.01, 0.5, 100)
rho = [LiCl.density(x, 25) for x in x_array]
plt.plot(x_array, rho, label="T=25°C")

rho = [LiCl.density(x, 50) for x in x_array]
plt.plot(x_array, rho, label="T=75°C")

rho = [LiCl.density(x, 100) for x in x_array]
plt.plot(x_array, rho, label="T=125°C")

rho = [LiCl.density(x, 150) for x in x_array]
plt.plot(x_array, rho, label="T=175°C")

rho = [LiCl.density(x, 200) for x in x_array]
plt.plot(x_array, rho, label="T=225°C")
# Out:
# Warning: The temperature 25 is below the solubility temperature 27.618986810741717 at x=0.46040404040404037.
# Warning: The temperature 25 is below the solubility temperature 32.477822209230624 at x=0.46535353535353535.
# Warning: The temperature 25 is below the solubility temperature 37.176991809553556 at x=0.4703030303030303.
# Warning: The temperature 25 is below the solubility temperature 41.71649561171017 at x=0.47525252525252526.
# Warning: The temperature 25 is below the solubility temperature 46.096333615700644 at x=0.4802020202020202.
# Warning: The temperature 25 is below the solubility temperature 50.3165058215248 at x=0.4851515151515151.
# Warning: The temperature 25 is below the solubility temperature 54.37701222918258 at x=0.4901010101010101.
# Warning: The temperature 25 is below the solubility temperature 58.277852838674335 at x=0.495050505050505.
# Warning: The temperature 25 is below the solubility temperature 62.01902764999994 at x=0.5.
# Warning: The temperature 50 is below the solubility temperature 50.3165058215248 at x=0.4851515151515151.
# Warning: The temperature 50 is below the solubility temperature 54.37701222918258 at x=0.4901010101010101.
# Warning: The temperature 50 is below the solubility temperature 58.277852838674335 at x=0.495050505050505.
# Warning: The temperature 50 is below the solubility temperature 62.01902764999994 at x=0.5.
