# %%
import functions as CaCl2
import numpy as np
import matplotlib.pyplot as plt

# %%
CaCl2.saturation_pressure(0.2, 20)
# Out:
# 1923.0165606787823

# %%
CaCl2.saturation_temperature(0.6, 1923.016)
# Out:
# ...
# 53.76147388208768

# %%
CaCl2.saturation_concentration(1923, 20)
# Out:
# 0.20000000000000015

# %%
CaCl2.dynamic_viscosity(0.2, 30)
# Out:
# 1.4887116841187071

# %%
CaCl2.crystallization_curve()

# %%
CaCl2.saturation_concentration(1500, 20)
# Out:
# 0.2990000000000002

# %%
CaCl2.pTDiagram()

# %% [markdown]
# x_array = np.linspace(0.01, 1, 100)
# rho = [CaCl2.density(x, 25) for x in x_array]
# plt.plot(x_array, rho, label="T=25°C")
#
# rho = [CaCl2.density(x, 50) for x in x_array]
# plt.plot(x_array, rho, label="T=75°C")
#
# rho = [CaCl2.density(x, 100) for x in x_array]
# plt.plot(x_array, rho, label="T=125°C")
#
# rho = [CaCl2.density(x, 150) for x in x_array]
# plt.plot(x_array, rho, label="T=175°C")
#
# rho = [CaCl2.density(x, 200) for x in x_array]
# plt.plot(x_array, rho, label="T=225°C")

# %%
CaCl2.specific_heat_capacity(0.2, 30)
# Out:
# 3.1335552126704584

# %%
x_array = np.linspace(0.01, 0.8, 100)
cp = [CaCl2.specific_heat_capacity(x, 26.5) for x in x_array]
plt.plot(x_array, cp, label="T=26.5°C")

# %%
x_array = np.linspace(0.01, 0.6, 100)
hd = [CaCl2.differential_enthalpy_AD(x, 100) for x in x_array]
plt.plot(x_array, hd)

# %%
x_array = np.linspace(0.01, 0.6, 100)
rho1 = [CaCl2.density(x, 30) for x in x_array]
# rho2 = [CaCl2.density(x, 100) for x in x_array]
xvals = [x/(1-x) for x in x_array]
plt.plot(xvals, rho1, label="30°C")
# plt.plot(xvals, x_array, rho2, label="100°C")
plt.grid()
plt.show()
