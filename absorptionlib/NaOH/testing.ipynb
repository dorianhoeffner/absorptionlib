# %%
import functions as NaOH
import numpy as np
import matplotlib.pyplot as plt

# %%
NaOH.saturation_pressure(0.5, 65)
# Out:
# 3195.510997020406

# %%
NaOH.saturation_temperature(0.1, 1200)
# Out:
# 11.148071858051129

# %%
NaOH.saturation_concentration(1000, 40)
# Out:
# 0.46000000000000035

# %%
NaOH.enthalpy(0.53, 26)
# Out:
# 348.5518981937465

# %%
NaOH.specific_heat_capacity(0.15, 20)
# Out:
# 4.184330420837787

# %%
NaOH.dynamic_viscosity(0.12, 20, 1000)
# Out:
# 0.0019386935023624817

# %%
NaOH.crystallization_curve()

# %%
NaOH.pTDiagram()

# %% [markdown]
# # OLD

# %%
LiCl.specific_heat_capacity(0.3, 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 LiCl.specific_heat_capacity(0.3, 20)
#
# NameError: name 'LiCl' is not defined

# %%
LiCl.diffusion_coefficient(0.2, 30)
# Out:
# 1.2173928714133192e-09

# %%
LiCl.dynamic_viscosity(0.2, 30)
# Out:
# 2.168187822484257

# %%
x_array = np.linspace(0.01, 0.8, 100)
cp = [LiCl.specific_heat_capacity(x, 26.5) for x in x_array]
plt.plot(x_array, cp, label="T=26.5°C")

# %%
x_array = np.linspace(0.01, 0.59, 100)
hd = [LiCl.differential_enthalpy_AD(x, 100) for x in x_array]
plt.plot(x_array, hd)

# %%
LiCl.saturation_pressure(0.3, 20)
# Out:
# 970.8232575409631

# %%
LiCl.saturation_temperature(0.3, 970.8232575409631)
# Out:
# 20.0

# %%
LiCl.saturation_concentration(970.8232575409631, 20)
# Out:
# 0.30000000000000004

# %%
LiCl.crystallization_curve()

# %%
x_array = np.linspace(0.01, 0.56, 100)
rho = [LiCl.density(x, 20) for x in x_array]
xvals = [x/(1-x) for x in x_array]
plt.plot(xvals, rho)
plt.grid()

# %%
LiCl.pTDiagram()

# %%
x_array = np.linspace(0.01, 1, 100)
rho = [CaCl2.density(x, 25) for x in x_array]
plt.plot(x_array, rho, label="T=25°C")

rho = [CaCl2.density(x, 50) for x in x_array]
plt.plot(x_array, rho, label="T=75°C")

rho = [CaCl2.density(x, 100) for x in x_array]
plt.plot(x_array, rho, label="T=125°C")

rho = [CaCl2.density(x, 150) for x in x_array]
plt.plot(x_array, rho, label="T=175°C")

rho = [CaCl2.density(x, 200) for x in x_array]
plt.plot(x_array, rho, label="T=225°C")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 x_array = np.linspace(0.01, 1, 100)
# ----> 2 rho = [CaCl2.density(x, 25) for x in x_array]
#       3 plt.plot(x_array, rho, label="T=25°C")
#       5 rho = [CaCl2.density(x, 50) for x in x_array]
#
# Cell In[13], line 2, in <listcomp>(.0)
#       1 x_array = np.linspace(0.01, 1, 100)
# ----> 2 rho = [CaCl2.density(x, 25) for x in x_array]
#       3 plt.plot(x_array, rho, label="T=25°C")
#       5 rho = [CaCl2.density(x, 50) for x in x_array]
#
# NameError: name 'CaCl2' is not defined

# %%
rho
# Out:
# [array(nan),
#  array(nan),
#  array(0.99868613),
#  array(1.00594347),
#  array(1.01320081),
#  array(1.02056855),
#  array(1.02812144),
#  array(1.03567433),
#  array(1.04295646),
#  array(1.04985257),
#  array(1.05674869),
#  array(1.06362381),
#  array(1.07047336),
#  array(1.07732292),
#  array(1.08407079),
#  array(1.09066522),
#  array(1.09725964),
#  array(1.10409338),
#  array(1.11108884),
#  array(1.1180843),
#  array(1.12457008),
#  array(1.1309903),
#  array(1.13741051),
#  array(1.1437317),
#  array(1.15004985),
#  array(1.15635282),
#  array(1.16254739),
#  array(1.16874195),
#  array(1.17493651),
#  array(1.18118453),
#  array(1.18744086),
#  array(1.19369719),
#  array(1.19974051),
#  array(1.20561815),
#  array(1.21149579),
#  array(1.21747541),
#  array(1.22359644),
#  array(1.22971746),
#  array(1.23566444),
#  array(1.24124328),
#  array(1.24682212),
#  array(1.25245176),
#  array(1.25819231),
#  array(1.26393285),
#  array(1.26957695),
#  array(1.27500368),
# ...
